# %% [markdown]
# ---
# <center>
#
# # **TALLER 1**
#
# Escriba los nombres
# ---

# %% [markdown]
# ## A Continuación se carga y se muestra una base de datos sobre los graduados en Colombia en el periodo de 2018-2021.

# %%
import pandas as pd
graduados=pd.read_excel("https://github.com/Wilsonsr/Programacion-en-Lenguajes-Estadisticos/raw/main/BASES/graduados_2018_2021.xlsx")
graduados.head(5)
# Out:
#    CÓDIGO DE LA INSTITUCIÓN  IES_PADRE  \
# 0                      1101       1101
# 1                      1101       1101
# 2                      1101       1101
# 3                      1101       1101
# 4                      1101       1101
#
#   INSTITUCIÓN DE EDUCACIÓN SUPERIOR (IES) PRINCIPAL O SECCIONAL  \
# 0        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# 1        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# 2        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# 3        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
# 4        UNIVERSIDAD NACIONAL DE COLOMBIA             Principal
#
#    ID SECTOR IES SECTOR IES  ID CARACTER CARACTER IES  \
# 0              1    OFICIAL            4  Universidad
# 1              1    OFICIAL            4  Universidad
# 2              1    OFICIAL            4  Universidad
# 3              1    OFICIAL            4  Universidad
# 4              1    OFICIAL            4  Universidad
#
# ...

# %% [markdown]
# **Cual es el total de graduados en el país de 2018-2021 diferenciando pregrado y posgrado  ¿de estos cuantos son mujeres y cuantos so hombres?**

# %%
# Escriba su código

# %% [markdown]
# **Cree un DataFrame llamada `nuevo_garduados`  que contenga sólo las columnas `AÑO`, `PROGRAMA ACADÉMICO`,`SEXO`, `SEMESTRE`, `GRADUADOS` en ese orden. Imprima el encabezado.**

# %%
# Escriba su código

# %% [markdown]
# **Para el área del conocimiento de Ciencias de la Salud indique el número de  tecnicos, tecnologos y universitarios se han graduado por año**

# %%
# Escriba su código

# %% [markdown]
# **¿Cuantos Estudiantes estudiantes se han graduado desde el año 2018 de la Especialización en estadística aplicada de la fundacion universitaria los libertadores?**

# %%
# Escriba su código

# %% [markdown]
# **De acuerdo con la base de datos  de cuantos programas  de medicina  en Bogotá hubo graduados  Además elabore una tabla que indique  los graduados semestre a semestre desde 2018 de estos programas**

# %%
# Escriba su código

# %% [markdown]
#  **Indique el Número de programas en 2021 por nivel de formación y sector**

# %%
# Escriba su código

# %% [markdown]
# **Indicar la cantidad de programas por metodología y por nivel académico  por cada departamento**

# %%
#Escriba su código

# %% [markdown]
# Considere la siguiente base de datos de población(DANE) por departamento en Colombia de los años 2018-2021

# %%
poblacion=pd.read_excel("https://github.com/Wilsonsr/Programacion-en-Lenguajes-Estadisticos/raw/main/BASES/poblacion.xlsx")
poblacion
# Out:
#     Codepto                                       DEPARTAMENTO     2018  \
# 0         5                                          ANTIOQUIA  6407102
# 1         8                                          ATLÁNTICO  2535517
# 2        11                                       BOGOTÁ, D.C.  7412566
# 3        13                                            BOLÍVAR  2070110
# 4        15                                             BOYACÁ  1217376
# 5        17                                             CALDAS   998255
# 6        18                                            CAQUETÁ   401849
# 7        19                                              CAUCA  1464488
# 8        20                                              CESAR  1200574
# 9        23                                            CÓRDOBA  1784783
# 10       25                                       CUNDINAMARCA  2919060
# 11       27                                              CHOCÓ   534826
# ...

# %% [markdown]
# Leer el siguiente artículo
# https://orientacion.universia.net.co/infodetail/orientacion/consejos/departamentos-que-destacan-en-educacion-superior-5799.html
#
# calcular  el  número de graduados en posgrado por cada 100.000 habitantes para cada uno de los departamentos para cada año y departamento analizar los resultados
